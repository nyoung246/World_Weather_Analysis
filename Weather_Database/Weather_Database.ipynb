# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 735

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count.
    record_count += 1

    # Run an API request for each of the cities.
    try:
    
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description,
                          "Date": city_date})

    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass


# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | kavieng
# Processing Record 2 of Set 1 | hermanus
# Processing Record 3 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 4 of Set 1 | upernavik
# Processing Record 5 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 6 of Set 1 | vaini
# Processing Record 7 of Set 1 | zinder
# Processing Record 8 of Set 1 | tungkang
# City not found. Skipping...
# Processing Record 9 of Set 1 | butaritari
# Processing Record 10 of Set 1 | castro
# Processing Record 11 of Set 1 | burnie
# Processing Record 12 of Set 1 | albany
# Processing Record 13 of Set 1 | lossiemouth
# Processing Record 14 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 15 of Set 1 | dikson
# Processing Record 16 of Set 1 | saint-georges
# Processing Record 17 of Set 1 | alofi
# Processing Record 18 of Set 1 | arraial do cabo
# Processing Record 19 of Set 1 | nikolskoye
# Processing Record 20 of Set 1 | evanston
# Processing Record 21 of Set 1 | vila franca do campo
# Processing Record 22 of Set 1 | mataura
# Processing Record 23 of Set 1 | tiksi
# Processing Record 24 of Set 1 | busselton
# Processing Record 25 of Set 1 | ancud
# Processing Record 26 of Set 1 | hamilton
# Processing Record 27 of Set 1 | moiyabana
# City not found. Skipping...
# Processing Record 28 of Set 1 | jamestown
# Processing Record 29 of Set 1 | hithadhoo
# Processing Record 30 of Set 1 | acapulco
# Processing Record 31 of Set 1 | tir pol
# City not found. Skipping...
# Processing Record 32 of Set 1 | belmonte
# Processing Record 33 of Set 1 | ushuaia
# Processing Record 34 of Set 1 | kingman
# Processing Record 35 of Set 1 | kerkira
# City not found. Skipping...
# Processing Record 36 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 37 of Set 1 | sistranda
# Processing Record 38 of Set 1 | zambezi
# Processing Record 39 of Set 1 | rikitea
# Processing Record 40 of Set 1 | ahipara
# Processing Record 41 of Set 1 | tulun
# Processing Record 42 of Set 1 | tura
# Processing Record 43 of Set 1 | ribeira grande
# Processing Record 44 of Set 1 | palabuhanratu
# City not found. Skipping...
# Processing Record 45 of Set 1 | chapleau
# Processing Record 46 of Set 1 | port elizabeth
# Processing Record 47 of Set 1 | rocha
# Processing Record 48 of Set 1 | sao joao da barra
# Processing Record 49 of Set 1 | avarua
# Processing Record 50 of Set 1 | portland
# Processing Record 1 of Set 2 | mahebourg
# Processing Record 2 of Set 2 | navalmoral de la mata
# Processing Record 3 of Set 2 | soma
# Processing Record 4 of Set 2 | asosa
# Processing Record 5 of Set 2 | cape town
# Processing Record 6 of Set 2 | new norfolk
# Processing Record 7 of Set 2 | kalakamati
# Processing Record 8 of Set 2 | punta arenas
# Processing Record 9 of Set 2 | dong hoi
# Processing Record 10 of Set 2 | piney green
# Processing Record 11 of Set 2 | sitka
# Processing Record 12 of Set 2 | jamame
# Processing Record 13 of Set 2 | kapaa
# Processing Record 14 of Set 2 | atuona
# Processing Record 15 of Set 2 | sorland
# Processing Record 16 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 17 of Set 2 | neuquen
# Processing Record 18 of Set 2 | codrington
# Processing Record 19 of Set 2 | college
# Processing Record 20 of Set 2 | chokurdakh
# Processing Record 21 of Set 2 | barstow
# Processing Record 22 of Set 2 | puerto ayora
# Processing Record 23 of Set 2 | sahuaripa
# Processing Record 24 of Set 2 | vestmannaeyjar
# Processing Record 25 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 26 of Set 2 | bengkulu
# Processing Record 27 of Set 2 | tuktoyaktuk
# Processing Record 28 of Set 2 | vila
# Processing Record 29 of Set 2 | bambous virieux
# Processing Record 30 of Set 2 | severnoye
# Processing Record 31 of Set 2 | georgetown
# Processing Record 32 of Set 2 | baykit
# Processing Record 33 of Set 2 | lebu
# Processing Record 34 of Set 2 | waddan
# Processing Record 35 of Set 2 | hilo
# Processing Record 36 of Set 2 | bredasdorp
# Processing Record 37 of Set 2 | ponta do sol
# Processing Record 38 of Set 2 | plover
# Processing Record 39 of Set 2 | torbay
# Processing Record 40 of Set 2 | karakendzha
# City not found. Skipping...
# Processing Record 41 of Set 2 | bathsheba
# Processing Record 42 of Set 2 | bluff
# Processing Record 43 of Set 2 | fagernes
# Processing Record 44 of Set 2 | namatanai
# Processing Record 45 of Set 2 | ilulissat
# Processing Record 46 of Set 2 | tirodi
# Processing Record 47 of Set 2 | labuan
# Processing Record 48 of Set 2 | cayenne
# Processing Record 49 of Set 2 | vilyuysk
# Processing Record 50 of Set 2 | clyde river
# Processing Record 1 of Set 3 | khani
# Processing Record 2 of Set 3 | novopokrovka
# Processing Record 3 of Set 3 | zhigansk
# Processing Record 4 of Set 3 | cairns
# Processing Record 5 of Set 3 | maragogi
# Processing Record 6 of Set 3 | port alfred
# Processing Record 7 of Set 3 | sabang
# Processing Record 8 of Set 3 | asifabad
# Processing Record 9 of Set 3 | dingle
# Processing Record 10 of Set 3 | nichinan
# Processing Record 11 of Set 3 | olafsvik
# Processing Record 12 of Set 3 | kobojango
# City not found. Skipping...
# Processing Record 13 of Set 3 | saint-philippe
# Processing Record 14 of Set 3 | kendari
# Processing Record 15 of Set 3 | east london
# Processing Record 16 of Set 3 | serebryansk
# Processing Record 17 of Set 3 | berdigestyakh
# Processing Record 18 of Set 3 | zyryanka
# Processing Record 19 of Set 3 | visnes
# Processing Record 20 of Set 3 | ebolowa
# Processing Record 21 of Set 3 | mezhova
# Processing Record 22 of Set 3 | lasa
# Processing Record 23 of Set 3 | great falls
# Processing Record 24 of Set 3 | sovetskiy
# Processing Record 25 of Set 3 | kieta
# Processing Record 26 of Set 3 | kaitangata
# Processing Record 27 of Set 3 | bilma
# Processing Record 28 of Set 3 | hasaki
# Processing Record 29 of Set 3 | coquimbo
# Processing Record 30 of Set 3 | pangnirtung
# Processing Record 31 of Set 3 | kandrian
# Processing Record 32 of Set 3 | nara
# Processing Record 33 of Set 3 | vanimo
# Processing Record 34 of Set 3 | qasigiannguit
# Processing Record 35 of Set 3 | omsukchan
# Processing Record 36 of Set 3 | etropole
# Processing Record 37 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 38 of Set 3 | pagman
# City not found. Skipping...
# Processing Record 39 of Set 3 | qaanaaq
# Processing Record 40 of Set 3 | hibbing
# Processing Record 41 of Set 3 | esperance
# Processing Record 42 of Set 3 | kargasok
# Processing Record 43 of Set 3 | fort nelson
# Processing Record 44 of Set 3 | saint-joseph
# Processing Record 45 of Set 3 | kalikino
# Processing Record 46 of Set 3 | rio branco
# Processing Record 47 of Set 3 | sayyan
# Processing Record 48 of Set 3 | hobyo
# Processing Record 49 of Set 3 | mao
# Processing Record 50 of Set 3 | zhoucheng
# Processing Record 1 of Set 4 | faanui
# Processing Record 2 of Set 4 | saskylakh
# Processing Record 3 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 4 of Set 4 | alnashi
# Processing Record 5 of Set 4 | hobart
# Processing Record 6 of Set 4 | mvuma
# Processing Record 7 of Set 4 | matay
# Processing Record 8 of Set 4 | nanortalik
# Processing Record 9 of Set 4 | cherskiy
# Processing Record 10 of Set 4 | khatanga
# Processing Record 11 of Set 4 | mangrol
# Processing Record 12 of Set 4 | tasiilaq
# Processing Record 13 of Set 4 | pevek
# Processing Record 14 of Set 4 | guatape
# Processing Record 15 of Set 4 | kehychivka
# Processing Record 16 of Set 4 | lima
# Processing Record 17 of Set 4 | los llanos de aridane
# Processing Record 18 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 19 of Set 4 | roscrea
# Processing Record 20 of Set 4 | thompson
# Processing Record 21 of Set 4 | kijang
# Processing Record 22 of Set 4 | pangody
# Processing Record 23 of Set 4 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 24 of Set 4 | yekaterinovka
# Processing Record 25 of Set 4 | makungu
# Processing Record 26 of Set 4 | ostrovnoy
# Processing Record 27 of Set 4 | ratnagiri
# Processing Record 28 of Set 4 | bocas del toro
# Processing Record 29 of Set 4 | bouna
# Processing Record 30 of Set 4 | presidencia roque saenz pena
# Processing Record 31 of Set 4 | barrow
# Processing Record 32 of Set 4 | ngukurr
# City not found. Skipping...
# Processing Record 33 of Set 4 | noshiro
# Processing Record 34 of Set 4 | kasama
# Processing Record 35 of Set 4 | kutum
# Processing Record 36 of Set 4 | bubaque
# Processing Record 37 of Set 4 | ramjibanpur
# Processing Record 38 of Set 4 | airai
# Processing Record 39 of Set 4 | meyungs
# City not found. Skipping...
# Processing Record 40 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 41 of Set 4 | constitucion
# Processing Record 42 of Set 4 | sao filipe
# Processing Record 43 of Set 4 | mrirt
# City not found. Skipping...
# Processing Record 44 of Set 4 | chifeng
# Processing Record 45 of Set 4 | wuzhou
# Processing Record 46 of Set 4 | aykhal
# Processing Record 47 of Set 4 | jasper
# Processing Record 48 of Set 4 | mar del plata
# Processing Record 49 of Set 4 | middle island
# Processing Record 50 of Set 4 | san patricio
# Processing Record 1 of Set 5 | mana
# Processing Record 2 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 3 of Set 5 | bandarbeyla
# Processing Record 4 of Set 5 | salto
# Processing Record 5 of Set 5 | sharya
# Processing Record 6 of Set 5 | jiazi
# Processing Record 7 of Set 5 | iqaluit
# Processing Record 8 of Set 5 | padang
# Processing Record 9 of Set 5 | uyuni
# Processing Record 10 of Set 5 | puerto quijarro
# Processing Record 11 of Set 5 | kodiak
# Processing Record 12 of Set 5 | vostok
# Processing Record 13 of Set 5 | mareeba
# Processing Record 14 of Set 5 | longyearbyen
# Processing Record 15 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 16 of Set 5 | kruisfontein
# Processing Record 17 of Set 5 | turukhansk
# Processing Record 18 of Set 5 | antofagasta
# Processing Record 19 of Set 5 | tiznit
# Processing Record 20 of Set 5 | mogzon
# Processing Record 21 of Set 5 | la sarre
# Processing Record 22 of Set 5 | souillac
# Processing Record 23 of Set 5 | kamaishi
# Processing Record 24 of Set 5 | verkhnevilyuysk
# Processing Record 25 of Set 5 | waynesboro
# Processing Record 26 of Set 5 | bardiyah
# Processing Record 27 of Set 5 | scarborough
# Processing Record 28 of Set 5 | iquique
# Processing Record 29 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 30 of Set 5 | kathu
# Processing Record 31 of Set 5 | dwarka
# Processing Record 32 of Set 5 | unye
# City not found. Skipping...
# Processing Record 33 of Set 5 | tuensang
# Processing Record 34 of Set 5 | celestun
# Processing Record 35 of Set 5 | gallup
# Processing Record 36 of Set 5 | betioky
# Processing Record 37 of Set 5 | nelson bay
# Processing Record 38 of Set 5 | igrim
# Processing Record 39 of Set 5 | klaksvik
# Processing Record 40 of Set 5 | kaspiyskiy
# Processing Record 41 of Set 5 | carnarvon
# Processing Record 42 of Set 5 | susuman
# Processing Record 43 of Set 5 | oxford
# Processing Record 44 of Set 5 | bethel
# Processing Record 45 of Set 5 | arona
# Processing Record 46 of Set 5 | asau
# Processing Record 47 of Set 5 | sur
# Processing Record 48 of Set 5 | labuhan
# Processing Record 49 of Set 5 | slave lake
# Processing Record 50 of Set 5 | labelle
# Processing Record 1 of Set 6 | paranhos
# Processing Record 2 of Set 6 | viligili
# City not found. Skipping...
# Processing Record 3 of Set 6 | paris
# Processing Record 4 of Set 6 | rungata
# City not found. Skipping...
# Processing Record 5 of Set 6 | laje
# Processing Record 6 of Set 6 | caruray
# Processing Record 7 of Set 6 | kilrush
# Processing Record 8 of Set 6 | armidale
# Processing Record 9 of Set 6 | athgarh
# City not found. Skipping...
# Processing Record 10 of Set 6 | pacific grove
# Processing Record 11 of Set 6 | dondo
# Processing Record 12 of Set 6 | haines junction
# Processing Record 13 of Set 6 | narsaq
# Processing Record 14 of Set 6 | vila velha
# Processing Record 15 of Set 6 | gat
# Processing Record 16 of Set 6 | namibe
# Processing Record 17 of Set 6 | matara
# Processing Record 18 of Set 6 | culipapa
# City not found. Skipping...
# Processing Record 19 of Set 6 | ardistan
# City not found. Skipping...
# Processing Record 20 of Set 6 | abha
# Processing Record 21 of Set 6 | qafsah
# City not found. Skipping...
# Processing Record 22 of Set 6 | pisco
# Processing Record 23 of Set 6 | yellowknife
# Processing Record 24 of Set 6 | waitati
# Processing Record 25 of Set 6 | leningradskiy
# Processing Record 26 of Set 6 | barawe
# City not found. Skipping...
# Processing Record 27 of Set 6 | batagay-alyta
# Processing Record 28 of Set 6 | chardara
# Processing Record 29 of Set 6 | bolungarvik
# City not found. Skipping...
# Processing Record 30 of Set 6 | gari
# Processing Record 31 of Set 6 | ormara
# Processing Record 32 of Set 6 | majene
# Processing Record 33 of Set 6 | victoria
# Processing Record 34 of Set 6 | wolmaranstad
# City not found. Skipping...
# Processing Record 35 of Set 6 | kantunilkin
# Processing Record 36 of Set 6 | harper
# Processing Record 37 of Set 6 | seoul
# Processing Record 38 of Set 6 | bentiu
# Processing Record 39 of Set 6 | srednekolymsk
# Processing Record 40 of Set 6 | irpa irpa
# Processing Record 41 of Set 6 | santa fe
# Processing Record 42 of Set 6 | the pas
# Processing Record 43 of Set 6 | kampong thum
# Processing Record 44 of Set 6 | stokmarknes
# Processing Record 45 of Set 6 | guerrero negro
# Processing Record 46 of Set 6 | yar-sale
# Processing Record 47 of Set 6 | wanning
# Processing Record 48 of Set 6 | xinzhou
# Processing Record 49 of Set 6 | blackfoot
# Processing Record 50 of Set 6 | okha
# Processing Record 1 of Set 7 | zhanaozen
# Processing Record 2 of Set 7 | lagoa
# Processing Record 3 of Set 7 | severo-kurilsk
# Processing Record 4 of Set 7 | lins
# Processing Record 5 of Set 7 | meiganga
# Processing Record 6 of Set 7 | kiama
# Processing Record 7 of Set 7 | saldanha
# Processing Record 8 of Set 7 | sioux lookout
# Processing Record 9 of Set 7 | dunedin
# Processing Record 10 of Set 7 | berlevag
# Processing Record 11 of Set 7 | ribeira brava
# Processing Record 12 of Set 7 | san quintin
# Processing Record 13 of Set 7 | teguldet
# Processing Record 14 of Set 7 | halalo
# City not found. Skipping...
# Processing Record 15 of Set 7 | nemuro
# Processing Record 16 of Set 7 | north bend
# Processing Record 17 of Set 7 | bestobe
# Processing Record 18 of Set 7 | norman wells
# Processing Record 19 of Set 7 | margate
# Processing Record 20 of Set 7 | tarudant
# City not found. Skipping...
# Processing Record 21 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 22 of Set 7 | comodoro rivadavia
# Processing Record 23 of Set 7 | vardo
# Processing Record 24 of Set 7 | muskegon
# Processing Record 25 of Set 7 | nome
# Processing Record 26 of Set 7 | salvacion
# Processing Record 27 of Set 7 | grand gaube
# Processing Record 28 of Set 7 | wencheng
# Processing Record 29 of Set 7 | touros
# Processing Record 30 of Set 7 | makhinjauri
# Processing Record 31 of Set 7 | geraldton
# Processing Record 32 of Set 7 | tonder
# Processing Record 33 of Set 7 | nipawin
# Processing Record 34 of Set 7 | kamenskoye
# City not found. Skipping...
# Processing Record 35 of Set 7 | sechura
# Processing Record 36 of Set 7 | cockburn harbour
# City not found. Skipping...
# Processing Record 37 of Set 7 | port-gentil
# Processing Record 38 of Set 7 | margherita
# Processing Record 39 of Set 7 | tabiauea
# City not found. Skipping...
# Processing Record 40 of Set 7 | talnakh
# Processing Record 41 of Set 7 | hofn
# Processing Record 42 of Set 7 | flinders
# Processing Record 43 of Set 7 | pasni
# Processing Record 44 of Set 7 | cidreira
# Processing Record 45 of Set 7 | laguna
# Processing Record 46 of Set 7 | chara
# Processing Record 47 of Set 7 | shelopugino
# Processing Record 48 of Set 7 | mazagao
# Processing Record 49 of Set 7 | cochrane
# Processing Record 50 of Set 7 | tuatapere
# Processing Record 1 of Set 8 | cortez
# Processing Record 2 of Set 8 | qiongshan
# Processing Record 3 of Set 8 | lavrentiya
# Processing Record 4 of Set 8 | itacare
# Processing Record 5 of Set 8 | cabo san lucas
# Processing Record 6 of Set 8 | rabaul
# Processing Record 7 of Set 8 | lazdijai
# Processing Record 8 of Set 8 | padampur
# Processing Record 9 of Set 8 | mahajanga
# Processing Record 10 of Set 8 | katsuura
# Processing Record 11 of Set 8 | isangel
# Processing Record 12 of Set 8 | ndouci
# City not found. Skipping...
# Processing Record 13 of Set 8 | mineiros
# Processing Record 14 of Set 8 | burica
# City not found. Skipping...
# Processing Record 15 of Set 8 | wazzan
# City not found. Skipping...
# Processing Record 16 of Set 8 | kato khorion
# Processing Record 17 of Set 8 | catamarca
# Processing Record 18 of Set 8 | ossora
# Processing Record 19 of Set 8 | luanda
# Processing Record 20 of Set 8 | kahului
# Processing Record 21 of Set 8 | lorengau
# Processing Record 22 of Set 8 | lotofaga
# Processing Record 23 of Set 8 | vung tau
# Processing Record 24 of Set 8 | zavoaia
# Processing Record 25 of Set 8 | mount gambier
# Processing Record 26 of Set 8 | yagoua
# Processing Record 27 of Set 8 | caravelas
# Processing Record 28 of Set 8 | maturin
# Processing Record 29 of Set 8 | dudinka
# Processing Record 30 of Set 8 | lashio
# Processing Record 31 of Set 8 | mumford
# Processing Record 32 of Set 8 | maralal
# Processing Record 33 of Set 8 | coihaique
# Processing Record 34 of Set 8 | cacak
# Processing Record 35 of Set 8 | khobi
# Processing Record 36 of Set 8 | aginskoye
# Processing Record 37 of Set 8 | atar
# Processing Record 38 of Set 8 | yirol
# City not found. Skipping...
# Processing Record 39 of Set 8 | san pedro
# Processing Record 40 of Set 8 | aras
# Processing Record 41 of Set 8 | lyuban
# Processing Record 42 of Set 8 | mingaora
# Processing Record 43 of Set 8 | kidal
# Processing Record 44 of Set 8 | zhezkazgan
# Processing Record 45 of Set 8 | umzimvubu
# City not found. Skipping...
# Processing Record 46 of Set 8 | poltavka
# Processing Record 47 of Set 8 | kotaparh
# Processing Record 48 of Set 8 | millbrook
# Processing Record 49 of Set 8 | huntingdon
# Processing Record 50 of Set 8 | yatou
# Processing Record 1 of Set 9 | dongsheng
# Processing Record 2 of Set 9 | kautokeino
# Processing Record 3 of Set 9 | yacuiba
# Processing Record 4 of Set 9 | mpanda
# Processing Record 5 of Set 9 | mecca
# Processing Record 6 of Set 9 | olinda
# Processing Record 7 of Set 9 | aswan
# Processing Record 8 of Set 9 | luis correia
# Processing Record 9 of Set 9 | port-cartier
# Processing Record 10 of Set 9 | tchollire
# Processing Record 11 of Set 9 | tucuman
# Processing Record 12 of Set 9 | ploemeur
# Processing Record 13 of Set 9 | cumra
# Processing Record 14 of Set 9 | marawi
# Processing Record 15 of Set 9 | hualmay
# Processing Record 16 of Set 9 | imeni poliny osipenko
# Processing Record 17 of Set 9 | okitipupa
# Processing Record 18 of Set 9 | vao
# Processing Record 19 of Set 9 | guayaramerin
# Processing Record 20 of Set 9 | kununurra
# Processing Record 21 of Set 9 | arlit
# Processing Record 22 of Set 9 | tome-acu
# City not found. Skipping...
# Processing Record 23 of Set 9 | boundiali
# Processing Record 24 of Set 9 | tuy hoa
# Processing Record 25 of Set 9 | crossville
# Processing Record 26 of Set 9 | khilok
# Processing Record 27 of Set 9 | carutapera
# Processing Record 28 of Set 9 | nishihara
# Processing Record 29 of Set 9 | yanan
# City not found. Skipping...
# Processing Record 30 of Set 9 | konevo
# Processing Record 31 of Set 9 | keetmanshoop
# Processing Record 32 of Set 9 | verkhniy baskunchak
# Processing Record 33 of Set 9 | saint combs
# City not found. Skipping...
# Processing Record 34 of Set 9 | santa cruz
# Processing Record 35 of Set 9 | ozerne
# Processing Record 36 of Set 9 | krasnoselkup
# Processing Record 37 of Set 9 | wabrzezno
# Processing Record 38 of Set 9 | cedar city
# Processing Record 39 of Set 9 | ambon
# Processing Record 40 of Set 9 | rio grande
# Processing Record 41 of Set 9 | gualeguay
# Processing Record 42 of Set 9 | julio de castilhos
# Processing Record 43 of Set 9 | yenagoa
# Processing Record 44 of Set 9 | reigate
# Processing Record 45 of Set 9 | hudson
# Processing Record 46 of Set 9 | tornio
# Processing Record 47 of Set 9 | nouadhibou
# Processing Record 48 of Set 9 | shingu
# Processing Record 49 of Set 9 | sinnamary
# Processing Record 50 of Set 9 | aldan
# Processing Record 1 of Set 10 | port arthur
# Processing Record 2 of Set 10 | tres arroyos
# Processing Record 3 of Set 10 | kayseri
# Processing Record 4 of Set 10 | mount isa
# Processing Record 5 of Set 10 | aquiraz
# Processing Record 6 of Set 10 | beaufort
# Processing Record 7 of Set 10 | kenai
# Processing Record 8 of Set 10 | kyren
# Processing Record 9 of Set 10 | ena
# Processing Record 10 of Set 10 | aksu
# Processing Record 11 of Set 10 | malanje
# Processing Record 12 of Set 10 | basavana bagevadi
# Processing Record 13 of Set 10 | saveh
# Processing Record 14 of Set 10 | verkhoyansk
# Processing Record 15 of Set 10 | chuy
# Processing Record 16 of Set 10 | pingliang
# Processing Record 17 of Set 10 | irara
# Processing Record 18 of Set 10 | port blair
# Processing Record 19 of Set 10 | barkot
# Processing Record 20 of Set 10 | riberalta
# Processing Record 21 of Set 10 | husavik
# Processing Record 22 of Set 10 | boras
# Processing Record 23 of Set 10 | warqla
# City not found. Skipping...
# Processing Record 24 of Set 10 | niceville
# Processing Record 25 of Set 10 | fortuna
# Processing Record 26 of Set 10 | bargal
# City not found. Skipping...
# Processing Record 27 of Set 10 | sao felix do xingu
# Processing Record 28 of Set 10 | champerico
# Processing Record 29 of Set 10 | samarai
# Processing Record 30 of Set 10 | saint-louis
# Processing Record 31 of Set 10 | benghazi
# Processing Record 32 of Set 10 | mehamn
# Processing Record 33 of Set 10 | ust-karsk
# Processing Record 34 of Set 10 | adrar
# Processing Record 35 of Set 10 | upata
# Processing Record 36 of Set 10 | sawtell
# Processing Record 37 of Set 10 | preobrazheniye
# Processing Record 38 of Set 10 | barkhan
# Processing Record 39 of Set 10 | pindi gheb
# Processing Record 40 of Set 10 | tiruvottiyur
# City not found. Skipping...
# Processing Record 41 of Set 10 | obuasi
# Processing Record 42 of Set 10 | praia da vitoria
# Processing Record 43 of Set 10 | carballo
# Processing Record 44 of Set 10 | changping
# Processing Record 45 of Set 10 | rawson
# Processing Record 46 of Set 10 | kayankulam
# Processing Record 47 of Set 10 | phan rang
# City not found. Skipping...
# Processing Record 48 of Set 10 | lompoc
# Processing Record 49 of Set 10 | xitla
# City not found. Skipping...
# Processing Record 50 of Set 10 | tanete
# Processing Record 1 of Set 11 | shelburne
# Processing Record 2 of Set 11 | havre-saint-pierre
# Processing Record 3 of Set 11 | kandi
# Processing Record 4 of Set 11 | fairbanks
# Processing Record 5 of Set 11 | xai-xai
# Processing Record 6 of Set 11 | pundaguitan
# Processing Record 7 of Set 11 | broome
# Processing Record 8 of Set 11 | merke
# Processing Record 9 of Set 11 | skibbereen
# Processing Record 10 of Set 11 | bonavista
# Processing Record 11 of Set 11 | sept-iles
# Processing Record 12 of Set 11 | fountain hills
# Processing Record 13 of Set 11 | yabluniv
# Processing Record 14 of Set 11 | narasaraopet
# Processing Record 15 of Set 11 | paternion
# Processing Record 16 of Set 11 | broken hill
# Processing Record 17 of Set 11 | ambilobe
# Processing Record 18 of Set 11 | canton
# Processing Record 19 of Set 11 | suhbaatar
# Processing Record 20 of Set 11 | fortuna foothills
# Processing Record 21 of Set 11 | skjervoy
# Processing Record 22 of Set 11 | akot
# Processing Record 23 of Set 11 | kariba
# Processing Record 24 of Set 11 | egvekinot
# Processing Record 25 of Set 11 | makarov
# Processing Record 26 of Set 11 | the valley
# Processing Record 27 of Set 11 | tashla
# Processing Record 28 of Set 11 | yuncheng
# Processing Record 29 of Set 11 | monrovia
# Processing Record 30 of Set 11 | ekibastuz
# Processing Record 31 of Set 11 | nan
# Processing Record 32 of Set 11 | biak
# Processing Record 33 of Set 11 | san cristobal
# Processing Record 34 of Set 11 | sumbe
# Processing Record 35 of Set 11 | brzi brod
# City not found. Skipping...
# Processing Record 36 of Set 11 | akyab
# Processing Record 37 of Set 11 | chapais
# Processing Record 38 of Set 11 | arandis
# Processing Record 39 of Set 11 | garden city
# Processing Record 40 of Set 11 | vanavara
# Processing Record 41 of Set 11 | fare
# Processing Record 42 of Set 11 | butembo
# Processing Record 43 of Set 11 | vagay
# Processing Record 44 of Set 11 | hohhot
# Processing Record 45 of Set 11 | bertoua
# Processing Record 46 of Set 11 | buala
# Processing Record 47 of Set 11 | awbari
# Processing Record 48 of Set 11 | west bay
# Processing Record 49 of Set 11 | sheridan
# Processing Record 50 of Set 11 | muzhi
# Processing Record 1 of Set 12 | lukh
# Processing Record 2 of Set 12 | longlac
# City not found. Skipping...
# Processing Record 3 of Set 12 | lumeje
# Processing Record 4 of Set 12 | el tigre
# Processing Record 5 of Set 12 | yunjinghong
# City not found. Skipping...
# Processing Record 6 of Set 12 | avera
# Processing Record 7 of Set 12 | beringovskiy
# Processing Record 8 of Set 12 | calella
# Processing Record 9 of Set 12 | lata
# Processing Record 10 of Set 12 | katangli
# Processing Record 11 of Set 12 | cockburn town
# Processing Record 12 of Set 12 | bereda
# Processing Record 13 of Set 12 | honiara
# Processing Record 14 of Set 12 | jaisalmer
# Processing Record 15 of Set 12 | el alto
# Processing Record 16 of Set 12 | svetlaya
# Processing Record 17 of Set 12 | otane
# Processing Record 18 of Set 12 | pochutla
# Processing Record 19 of Set 12 | karaul
# City not found. Skipping...
# Processing Record 20 of Set 12 | homer
# Processing Record 21 of Set 12 | mandera
# Processing Record 22 of Set 12 | evensk
# Processing Record 23 of Set 12 | kloulklubed
# Processing Record 24 of Set 12 | belaya kholunitsa
# Processing Record 25 of Set 12 | san policarpo
# Processing Record 26 of Set 12 | durg
# Processing Record 27 of Set 12 | colesberg
# Processing Record 28 of Set 12 | garm
# City not found. Skipping...
# Processing Record 29 of Set 12 | muros
# Processing Record 30 of Set 12 | merauke
# Processing Record 31 of Set 12 | lazaro cardenas
# Processing Record 32 of Set 12 | morant bay
# Processing Record 33 of Set 12 | inirida
# Processing Record 34 of Set 12 | choya
# Processing Record 35 of Set 12 | petropavlovsk-kamchatskiy
# Processing Record 36 of Set 12 | gunjur
# Processing Record 37 of Set 12 | vancouver
# Processing Record 38 of Set 12 | provideniya
# Processing Record 39 of Set 12 | san andres
# Processing Record 40 of Set 12 | hirara
# Processing Record 41 of Set 12 | faya
# Processing Record 42 of Set 12 | maine-soroa
# Processing Record 43 of Set 12 | kamen-rybolov
# Processing Record 44 of Set 12 | morondava
# Processing Record 45 of Set 12 | strezhevoy
# Processing Record 46 of Set 12 | tessalit
# Processing Record 47 of Set 12 | vermillion
# Processing Record 48 of Set 12 | dodola
# Processing Record 49 of Set 12 | nyuksenitsa
# Processing Record 50 of Set 12 | farmington
# Processing Record 1 of Set 13 | kimbe
# Processing Record 2 of Set 13 | bur gabo
# City not found. Skipping...
# Processing Record 3 of Set 13 | rosario
# Processing Record 4 of Set 13 | santa maria
# Processing Record 5 of Set 13 | les cayes
# Processing Record 6 of Set 13 | kjollefjord
# Processing Record 7 of Set 13 | quelimane
# Processing Record 8 of Set 13 | gurskoye
# City not found. Skipping...
# Processing Record 9 of Set 13 | jilib
# Processing Record 10 of Set 13 | gogrial
# Processing Record 11 of Set 13 | komsomolskiy
# Processing Record 12 of Set 13 | mahadday weyne
# City not found. Skipping...
# Processing Record 13 of Set 13 | salinas
# Processing Record 14 of Set 13 | chumikan
# Processing Record 15 of Set 13 | zahir pir
# Processing Record 16 of Set 13 | alamosa
# Processing Record 17 of Set 13 | bitburg
# Processing Record 18 of Set 13 | edd
# Processing Record 19 of Set 13 | baghdad
# Processing Record 20 of Set 13 | alugan
# Processing Record 21 of Set 13 | balkanabat
# Processing Record 22 of Set 13 | brae
# Processing Record 23 of Set 13 | sentyabrskiy
# City not found. Skipping...
# Processing Record 24 of Set 13 | pombas
# Processing Record 25 of Set 13 | aksehir
# Processing Record 26 of Set 13 | manuk mangkaw
# Processing Record 27 of Set 13 | fuyang
# Processing Record 28 of Set 13 | srandakan
# Processing Record 29 of Set 13 | bay roberts
# Processing Record 30 of Set 13 | bulgan
# Processing Record 31 of Set 13 | kalivia
# Processing Record 32 of Set 13 | emerald
# Processing Record 33 of Set 13 | jiddah
# City not found. Skipping...
# Processing Record 34 of Set 13 | uwayl
# City not found. Skipping...
# Processing Record 35 of Set 13 | poya
# Processing Record 36 of Set 13 | dolbeau
# City not found. Skipping...
# Processing Record 37 of Set 13 | orito
# Processing Record 38 of Set 13 | najran
# Processing Record 39 of Set 13 | pontianak
# Processing Record 40 of Set 13 | shimoda
# Processing Record 41 of Set 13 | dunmore east
# Processing Record 42 of Set 13 | devgarh
# Processing Record 43 of Set 13 | palu
# Processing Record 44 of Set 13 | hede
# Processing Record 45 of Set 13 | kinango
# Processing Record 46 of Set 13 | iisalmi
# Processing Record 47 of Set 13 | dubai
# Processing Record 48 of Set 13 | felidhoo
# City not found. Skipping...
# Processing Record 49 of Set 13 | abu jubayhah
# City not found. Skipping...
# Processing Record 50 of Set 13 | blyth
# Processing Record 1 of Set 14 | pringsewu
# Processing Record 2 of Set 14 | gornopravdinsk
# Processing Record 3 of Set 14 | sena madureira
# Processing Record 4 of Set 14 | bacungan
# Processing Record 5 of Set 14 | sirjan
# Processing Record 6 of Set 14 | oussouye
# Processing Record 7 of Set 14 | ipixuna
# Processing Record 8 of Set 14 | artigas
# Processing Record 9 of Set 14 | galveston
# Processing Record 10 of Set 14 | zapolyarnyy
# Processing Record 11 of Set 14 | wufeng
# Processing Record 12 of Set 14 | caborca
# Processing Record 13 of Set 14 | rizhao
# Processing Record 14 of Set 14 | ballina
# Processing Record 15 of Set 14 | helsinki
# Processing Record 16 of Set 14 | abu dhabi
# Processing Record 17 of Set 14 | kailua
# Processing Record 18 of Set 14 | gillette
# Processing Record 19 of Set 14 | vestmanna
# Processing Record 20 of Set 14 | honningsvag
# Processing Record 21 of Set 14 | gerash
# Processing Record 22 of Set 14 | nova olinda do norte
# Processing Record 23 of Set 14 | payo
# Processing Record 24 of Set 14 | sotouboua
# Processing Record 25 of Set 14 | nyaunglebin
# Processing Record 26 of Set 14 | itarema
# Processing Record 27 of Set 14 | bambari
# Processing Record 28 of Set 14 | ust-kut
# Processing Record 29 of Set 14 | lauro muller
# Processing Record 30 of Set 14 | stykkisholmur
# Processing Record 31 of Set 14 | maykain
# City not found. Skipping...
# Processing Record 32 of Set 14 | owo
# Processing Record 33 of Set 14 | lufilufi
# Processing Record 34 of Set 14 | mwene-ditu
# Processing Record 35 of Set 14 | almaznyy
# Processing Record 36 of Set 14 | acari
# Processing Record 37 of Set 14 | mentok
# City not found. Skipping...
# Processing Record 38 of Set 14 | halifax
# Processing Record 39 of Set 14 | launceston
# Processing Record 40 of Set 14 | barra velha
# Processing Record 41 of Set 14 | lamu
# Processing Record 42 of Set 14 | zimovniki
# Processing Record 43 of Set 14 | tautira
# Processing Record 44 of Set 14 | naryan-mar
# Processing Record 45 of Set 14 | nacala
# Processing Record 46 of Set 14 | simbahan
# Processing Record 47 of Set 14 | puerto escondido
# Processing Record 48 of Set 14 | ericeira
# Processing Record 49 of Set 14 | aklavik
# Processing Record 50 of Set 14 | kuching
# Processing Record 1 of Set 15 | saint george
# Processing Record 2 of Set 15 | pimentel
# Processing Record 3 of Set 15 | urumqi
# Processing Record 4 of Set 15 | saint-augustin
# Processing Record 5 of Set 15 | luderitz
# Processing Record 6 of Set 15 | richard toll
# City not found. Skipping...
# Processing Record 7 of Set 15 | tahta
# Processing Record 8 of Set 15 | ambodifototra
# City not found. Skipping...
# Processing Record 9 of Set 15 | yerbogachen
# Processing Record 10 of Set 15 | kristiinankaupunki
# Processing Record 11 of Set 15 | zhuhai
# Processing Record 12 of Set 15 | cardston
# Processing Record 13 of Set 15 | sumenep
# Processing Record 14 of Set 15 | yagodnoye
# Processing Record 15 of Set 15 | lipany
# Processing Record 16 of Set 15 | tavricheskoye
# Processing Record 17 of Set 15 | solton
# Processing Record 18 of Set 15 | mahalapye
# Processing Record 19 of Set 15 | kostomuksha
# Processing Record 20 of Set 15 | mardan
# Processing Record 21 of Set 15 | ciudad bolivar
# Processing Record 22 of Set 15 | ixtapa
# Processing Record 23 of Set 15 | esmeralda
# Processing Record 24 of Set 15 | manggar
# Processing Record 25 of Set 15 | saint-raymond
# Processing Record 26 of Set 15 | kulhudhuffushi
# Processing Record 27 of Set 15 | maloshuyka
# City not found. Skipping...
# Processing Record 28 of Set 15 | peoria
# Processing Record 29 of Set 15 | anito
# Processing Record 30 of Set 15 | hit
# Processing Record 31 of Set 15 | nyanza
# Processing Record 32 of Set 15 | ternate
# Processing Record 33 of Set 15 | seymchan
# Processing Record 34 of Set 15 | hami
# Processing Record 35 of Set 15 | mocuba
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 662

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0      Kavieng  -2.5744  150.7967     81.64        76           3        9.04
# 1     Hermanus -34.4187   19.2345     57.90        78          94        4.34
# 2    Upernavik  72.7868  -56.1549     43.11        79          26       13.22
# 3        Vaini -21.2000 -175.2000     71.76        83          20       21.85
# 4       Zinder  13.8072    8.9881     89.85        44          87       10.20
# 5   Butaritari   3.0707  172.7902     83.05        69          13        9.78
# 6       Castro -24.7911  -50.0119     50.13        82          69        2.80
# 7       Burnie -41.0667  145.9167     45.19        82          95        5.53
# 8       Albany  42.6001  -73.9662     76.87        74          82        1.01
# 9  Lossiemouth  57.7214   -3.2834     55.74        80         100        6.78
#
#   Country Current Description                 Date
# 0      PG           clear sky  2021-08-01 20:55:54
# 1      ZA     overcast clouds  2021-08-01 20:55:54
# 2      GL    scattered clouds  2021-08-01 20:55:55
# 3      TO          few clouds  2021-08-01 20:55:55
# 4      NE     overcast clouds  2021-08-01 20:55:56
# 5      KI          few clouds  2021-08-01 20:55:56
# 6      BR       broken clouds  2021-08-01 20:55:56
# 7      AU     overcast clouds  2021-08-01 20:55:56
# 8      US       broken clouds  2021-08-01 20:52:48
# 9      GB     overcast clouds  2021-08-01 20:55:57

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Kavieng      PG  -2.5744  150.7967     81.64        76           3
# 1     Hermanus      ZA -34.4187   19.2345     57.90        78          94
# 2    Upernavik      GL  72.7868  -56.1549     43.11        79          26
# 3        Vaini      TO -21.2000 -175.2000     71.76        83          20
# 4       Zinder      NE  13.8072    8.9881     89.85        44          87
# 5   Butaritari      KI   3.0707  172.7902     83.05        69          13
# 6       Castro      BR -24.7911  -50.0119     50.13        82          69
# 7       Burnie      AU -41.0667  145.9167     45.19        82          95
# 8       Albany      US  42.6001  -73.9662     76.87        74          82
# 9  Lossiemouth      GB  57.7214   -3.2834     55.74        80         100
#
#    Wind Speed Current Description
# 0        9.04           clear sky
# 1        4.34     overcast clouds
# 2       13.22    scattered clouds
# 3       21.85          few clouds
# 4       10.20     overcast clouds
# 5        9.78          few clouds
# 6        2.80       broken clouds
# 7        5.53     overcast clouds
# 8        1.01       broken clouds
# 9        6.78     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
